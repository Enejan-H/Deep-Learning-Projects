# %%
import pandas as pd
import numpy as np
from keras.preprocessing.image import load_img, img_to_array
import os

# Define paths and image dimensions
image_dir = '/Users/enejanhayytjanova/Desktop/My Githup/Deep-Learning-Projects/CNN_Project_Chlorophyll_measuring/train/cropped_images'  # Replace with your image directory path
chlorophyll_file = '/Users/enejanhayytjanova/Desktop/My Githup/Deep-Learning-Projects/CNN_Project_Chlorophyll_measuring/train/train_chlorophyll_level.txt'  # Replace with your chlorophyll values file path
img_height, img_width = 128, 128  # Replace with your target image size

# Load chlorophyll values from the text file
def load_chlorophyll_values(file_path):
    chlorophyll_dict = {}
    with open(file_path, 'r') as file:
        for line in file:
            img_name, value = line.strip().split()
            chlorophyll_dict[img_name] = float(value)
    return chlorophyll_dict

# Function to preprocess a single image
def preprocess_image(img_path):
    img = load_img(img_path, target_size=(img_height, img_width))
    img_array = img_to_array(img)
    img_array = img_array / 255.0  # Normalize to [0, 1]
    return img_array

# Create a DataFrame from images and their chlorophyll values
def create_dataframe(image_dir, chlorophyll_file):
    chlorophyll_values = load_chlorophyll_values(chlorophyll_file)
    
    image_data = []
    values = []
    
    for img_filename, value in chlorophyll_values.items():
        img_path = os.path.join(image_dir, img_filename)
        if os.path.exists(img_path):
            img_array = preprocess_image(img_path)
            image_data.append(img_array)
            values.append(value)
        else:
            print(f"Warning: Image file {img_filename} not found.")
    
    # Convert lists to numpy arrays
    X = np.array(image_data)
    y = np.array(values)
    
    # Create a DataFrame
    df = pd.DataFrame({
        'Image': list(X),  # Store image arrays as list entries
        'Chlorophyll': y
    })
    
    return df

# Example usage
df = create_dataframe(image_dir, chlorophyll_file)

# Display the DataFrame
print(df.head())
# Out:
# Warning: Image file soi1_image_3 not found.
# Warning: Image file soi1_image_4 not found.
# Warning: Image file soi1_image_5 not found.
# Warning: Image file soi1_image_6 not found.
# Warning: Image file soi1_image_7 not found.
# Warning: Image file soi1_image_8 not found.
# Warning: Image file soi1_image_9 not found.
# Warning: Image file soi1_image_10 not found.
# Warning: Image file soi1_image_11 not found.
# Warning: Image file soi1_image_12 not found.
# Warning: Image file soi1_image_13 not found.
# Warning: Image file soi1_image_14 not found.
# Warning: Image file soi1_image_15 not found.
# Warning: Image file soi1_image_16 not found.
# Warning: Image file soi1_image_17 not found.
# Warning: Image file soi1_image_18 not found.
# Warning: Image file soi2_image_3 not found.
# Warning: Image file soi2_image_4 not found.
# Warning: Image file soi2_image_5 not found.
# Warning: Image file soi2_image_6 not found.
# Warning: Image file soi2_image_7 not found.
# Warning: Image file soi2_image_8 not found.
# Warning: Image file soi2_image_9 not found.
# Warning: Image file soi2_image_10 not found.
# Warning: Image file soi2_image_11 not found.
# Warning: Image file soi2_image_12 not found.
# Warning: Image file soi2_image_13 not found.
# Warning: Image file soi2_image_14 not found.
# Warning: Image file soi2_image_15 not found.
# Warning: Image file soi2_image_16 not found.
# Warning: Image file soi2_image_17 not found.
# Warning: Image file soi2_image_18 not found.
# Warning: Image file soi3_image_3 not found.
# Warning: Image file soi3_image_4 not found.
# Warning: Image file soi3_image_5 not found.
# Warning: Image file soi3_image_6 not found.
# Warning: Image file soi3_image_7 not found.
# Warning: Image file soi3_image_8 not found.
# Warning: Image file soi3_image_9 not found.
# Warning: Image file soi3_image_10 not found.
# Warning: Image file soi3_image_11 not found.
# Warning: Image file soi3_image_12 not found.
# Warning: Image file soi3_image_13 not found.
# Warning: Image file soi3_image_14 not found.
# Warning: Image file soi3_image_15 not found.
# Warning: Image file soi3_image_16 not found.
# Warning: Image file soi3_image_17 not found.
# Warning: Image file soi3_image_18 not found.
# Warning: Image file soi4_image_3 not found.
# Warning: Image file soi4_image_4 not found.
# Warning: Image file soi4_image_5 not found.
# Warning: Image file soi4_image_6 not found.
# Warning: Image file soi4_image_7 not found.
# Warning: Image file soi4_image_8 not found.
# Warning: Image file soi4_image_9 not found.
# Warning: Image file soi4_image_10 not found.
# Warning: Image file soi4_image_11 not found.
# Warning: Image file soi4_image_12 not found.
# Warning: Image file soi4_image_13 not found.
# Warning: Image file soi4_image_14 not found.
# Warning: Image file soi4_image_15 not found.
# Warning: Image file soi4_image_16 not found.
# Warning: Image file soi4_image_17 not found.
# Warning: Image file soi4_image_18 not found.
# Warning: Image file soi5_image_3 not found.
# Warning: Image file soi5_image_4 not found.
# Warning: Image file soi5_image_5 not found.
# Warning: Image file soi5_image_6 not found.
# Warning: Image file soi5_image_7 not found.
# Warning: Image file soi5_image_8 not found.
# Warning: Image file soi5_image_9 not found.
# Warning: Image file soi5_image_10 not found.
# Warning: Image file soi5_image_11 not found.
# Warning: Image file soi5_image_12 not found.
# Warning: Image file soi5_image_13 not found.
# Warning: Image file soi5_image_14 not found.
# Warning: Image file soi5_image_15 not found.
# Warning: Image file soi5_image_16 not found.
# Warning: Image file soi5_image_17 not found.
# Warning: Image file soi5_image_18 not found.
# Warning: Image file soi6_image_3 not found.
# Warning: Image file soi6_image_4 not found.
# Warning: Image file soi6_image_5 not found.
# Warning: Image file soi6_image_6 not found.
# Warning: Image file soi6_image_7 not found.
# Warning: Image file soi6_image_8 not found.
# Warning: Image file soi6_image_9 not found.
# Warning: Image file soi6_image_10 not found.
# Warning: Image file soi6_image_11 not found.
# Warning: Image file soi6_image_12 not found.
# Warning: Image file soi6_image_13 not found.
# Warning: Image file soi6_image_14 not found.
# Warning: Image file soi6_image_15 not found.
# Warning: Image file soi6_image_16 not found.
# Warning: Image file soi6_image_17 not found.
# Warning: Image file soi6_image_18 not found.
# Warning: Image file soi7_image_3 not found.
# Warning: Image file soi7_image_4 not found.
# Warning: Image file soi7_image_5 not found.
# Warning: Image file soi7_image_6 not found.
# Warning: Image file soi7_image_7 not found.
# Warning: Image file soi7_image_8 not found.
# Warning: Image file soi7_image_9 not found.
# Warning: Image file soi7_image_10 not found.
# Warning: Image file soi7_image_11 not found.
# Warning: Image file soi7_image_12 not found.
# Warning: Image file soi7_image_13 not found.
# Warning: Image file soi7_image_14 not found.
# Warning: Image file soi7_image_15 not found.
# Warning: Image file soi7_image_16 not found.
# Warning: Image file soi7_image_17 not found.
# Warning: Image file soi7_image_18 not found.
# Warning: Image file soi9_image_3 not found.
# Warning: Image file soi9_image_4 not found.
# Warning: Image file soi9_image_5 not found.
# Warning: Image file soi9_image_6 not found.
# Warning: Image file soi9_image_7 not found.
# Warning: Image file soi9_image_8 not found.
# Warning: Image file soi9_image_9 not found.
# Warning: Image file soi9_image_10 not found.
# Warning: Image file soi9_image_11 not found.
# Warning: Image file soi9_image_12 not found.
# Warning: Image file soi9_image_13 not found.
# Warning: Image file soi9_image_14 not found.
# Warning: Image file soi9_image_15 not found.
# Warning: Image file soi9_image_16 not found.
# Warning: Image file soi9_image_17 not found.
# Warning: Image file soi9_image_18 not found.
# Warning: Image file soi1_late_image_1 not found.
# Warning: Image file soi1_late_image_2 not found.
# Warning: Image file soi1_late_image_4 not found.
# Warning: Image file soi1_late_image_5 not found.
# Warning: Image file soi2_late_image_1 not found.
# Warning: Image file soi2_late_image_2 not found.
# Warning: Image file soi2_late_image_4 not found.
# Warning: Image file soi2_late_image_5 not found.
# Warning: Image file soi3_late_image_1 not found.
# Warning: Image file soi3_late_image_2 not found.
# Warning: Image file soi3_late_image_4 not found.
# Warning: Image file soi3_late_image_5 not found.
# Warning: Image file soi4_late_image_1 not found.
# Warning: Image file soi4_late_image_2 not found.
# Warning: Image file soi4_late_image_4 not found.
# Warning: Image file soi4_late_image_5 not found.
# Warning: Image file soi5_late_image_1 not found.
# Warning: Image file soi5_late_image_2 not found.
# Warning: Image file soi5_late_image_4 not found.
# Warning: Image file soi5_late_image_5 not found.
# Warning: Image file soi6_late_image_1 not found.
# Warning: Image file soi6_late_image_2 not found.
# Warning: Image file soi6_late_image_4 not found.
# Warning: Image file soi6_late_image_5 not found.
# Warning: Image file soi7_late_image_1 not found.
# Warning: Image file soi7_late_image_2 not found.
# Warning: Image file soi7_late_image_4 not found.
# Warning: Image file soi7_late_image_5 not found.
# Warning: Image file soi9_late_image_1 not found.
# Warning: Image file soi9_late_image_2 not found.
# Warning: Image file soi9_late_image_4 not found.
# Warning: Image file soi9_late_image_5 not found.
# Empty DataFrame
# Columns: [Image, Chlorophyll]
# Index: []
